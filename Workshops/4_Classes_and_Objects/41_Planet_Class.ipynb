# %%
class Planet :
    def __init__(self, name, planet_type, star) :
        if not (isinstance(name, str) and isinstance(planet_type, str) and isinstance(star, str)) :
            raise TypeError("name, planet type, and star must be strings")

        if name == "" or planet_type == "" or star == "" :
            raise ValueError("name, planet_type, and star must be non-empty strings")
        
        self.name = name
        self.planet_type = planet_type
        self.star = star

    def orbit(self) :
        return f"{self.name} is orbiting around {self.star}"

    def __str__(self) :
        return f"Planet: {self.name} | Type: {self.planet_type} | Star: {self.star}"

# %%
planet_1 = Planet("Venus", "Terrestrial", "Sun")
planet_2 = Planet("Mars", "Terrestrial", "Sun")
planet_3 = Planet("Saturn", "Gas", "Sun")

print(planet_1.orbit())
print(planet_1)

print(planet_2.orbit())
print(planet_2)

print(planet_3.orbit())
print(planet_3)
# Out:
# Venus is orbiting around Sun
# Planet: Venus | Type: Terrestrial | Star: Sun
# Mars is orbiting around Sun
# Planet: Mars | Type: Terrestrial | Star: Sun
# Saturn is orbiting around Sun
# Planet: Saturn | Type: Gas | Star: Sun
