# %%
age = 19
name = ""
val = False

print("Answer: ", age or name)
print("Answer: ", val or age)
print("Answer: ", val or name)
# Out:
# Answer:  19
# Answer:  19
# Answer:

# %% [markdown]
# # Movie Ticket App

# %%
# Define variables
base_price  = 15
age         = 11
seat_type   = "Gold"
show_time   = "Evening"

is_member   = True
is_weekend  = False

discount    = 0
extra_charges = 0

service_changes = 0
final_price = 0

# %%
if (age > 17) :
    print("User is eligible to book a ticket")

if (age >= 21) :
    print("User is eligible for Evening shows.")
else :
    print("User is not eligible for Evening shows")
# Out:
# User is not eligible for Evening shows

# %%
if (is_member) :
    discount = 3
    print("User qualifies for membership discount")
else :
    print("User does not qualify for membership discount")

print(f"Discount: {discount}")
# Out:
# User qualifies for membership discount
# Discount: 3

# %%
if (is_weekend or show_time == "Evening") :
    extra_charges = 2
    print("Extra charges will be applied")
else :
    print("No extra charges will be applied")

print("Extra charges:", extra_charges)
# Out:
# Extra charges will be applied
# Extra charges: 2

# %%
if age >= 21 or age >= 18 and (show_time != "Evening" or is_member) :
    service_charges = 0
    if seat_type == "Premium" :
        service_charges = 5
    elif seat_type == "Gold" :
        service_charges = 3
    else :
        service_charges = 1
    
    print("Service charges:", service_charges)

    final_price = base_price + extra_charges + service_charges - discount
    
    print("Ticket booking condition satisfied")
else : 
    print("Ticket booking failed due to restrictions")

print("\nFinal price of ticket:", final_price or "Not calculated due to there existing conditions that are not satisfied")
# Out:
# Ticket booking failed due to restrictions
#
# Final price of ticket: Not calculated due to there existing conditions that are not satisfied
